# %%
##3. Perform Below Visualizations.
# Univariate Analysis
# Bi-Variate Analysis
# Multi-Variate Analysi

import pandas as pd

# %%
ds=pd.read_csv('Housing.csv')

# %%
ds
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
ds.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
import matplotlib.pyplot as plt
plt.hist(ds['price'])
# Out:
# (array([ 61., 163., 139.,  89.,  46.,  25.,  13.,   4.,   1.,   4.]),
#  array([ 1750000.,  2905000.,  4060000.,  5215000.,  6370000.,  7525000.,
#          8680000.,  9835000., 10990000., 12145000., 13300000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(ds['price'],dataset['area'])
# Out:
# <BarContainer object of 545 artists>

# %%
plt.plot(dataset['price'],dataset['parking'])

# %%
plt.boxplot(ds['price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2175e750df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2175e7603d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2175e750c40>],
#  'medians': [<matplotlib.lines.Line2D at 0x2175e760970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2175e760c40>],
#  'means': []}

# %%
plt.scatter(ds['price'],ds['area'])

# %%
data=ds['price'].value_counts()

# %%
data
# Out:
# 3500000     17
# 4200000     17
# 4900000     12
# 3150000      9
# 5600000      9
#             ..
# 6580000      1
# 4319000      1
# 4375000      1
# 4382000      1
# 13300000     1
# Name: price, Length: 219, dtype: int64

# %%
plt.pie(data,autopct='%.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x2175e81abb0>,
# ...
#  [Text(1.094722603837855, 0.10762165510001631, ''),
#   Text(1.0528067767672913, 0.3187442404073634, ''),
#   Text(0.9850949075428758, 0.4894772958300447, ''),
#   Text(0.9187784109680384, 0.60485223942633, ''),
#   Text(0.8511907650691254, 0.6967598448971044, ''),
#   Text(0.774447473656034, 0.7811729069468467, ''),
#   Text(0.6893740089972656, 0.8571834551127536, ''),
#   Text(0.6022016436218567, 0.9205178870718018, ''),
#   Text(0.5148628942398146, 0.9720680018059444, ''),
#   Text(0.4231476096420148, 1.0153551597614743, ''),
#   Text(0.3278354054841127, 1.0500114032290637, ''),
#   Text(0.2359336205080979, 1.074399984509466, ''),
#   Text(0.14855418850790492, 1.0899227739049946, ''),
#   Text(0.06020778879596861, 1.098351046873585, ''),
#   Text(-0.028530514963547342, 1.0996299421695988, ''),
#   Text(-0.11708310812785049, 1.0937511352182097, ''),
#   Text(-0.19864033576416046, 1.0819159010789619, ''),
# ...

# %%
plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.plot(ds['price'],ds['mainroad'])


plt.subplot(2,2,4)
plt.plot(ds['price'],ds['area'])

# %%
##4. Perform descriptive statistics on the dataset.
import pandas as pd
dataset=pd.read_csv('Housing.csv')

# %%
dataset
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
dataset.mean()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\1799472221.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
dataset.median()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\4167803218.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.median()
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
dataset.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
dataset.kurt()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\4113884262.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.kurt()
# price        1.960130
# area         2.751480
# bedrooms     0.728323
# bathrooms    2.164856
# stories      0.679404
# parking     -0.573063
# dtype: float64

# %%
dataset.max()
# Out:
# price                  13300000
# area                      16200
# bedrooms                      6
# bathrooms                     4
# stories                       4
# mainroad                    yes
# guestroom                   yes
# basement                    yes
# hotwaterheating             yes
# airconditioning             yes
# parking                       3
# furnishingstatus    unfurnished
# dtype: object

# %%
dataset.min()
# Out:
# price                 1750000
# area                     1650
# bedrooms                    1
# bathrooms                   1
# stories                     1
# mainroad                   no
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning            no
# parking                     0
# furnishingstatus    furnished
# dtype: object

# %%
dataset.var()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\2458428038.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.var()
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
dataset.std()
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\178401259.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.std()
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %%
##5. Handle the Missing values
dataset.fillna(dataset.mean(), inplace=True)
# Out:
# C:\Users\chand\AppData\Local\Temp\ipykernel_20900\2339913823.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   dataset.fillna(dataset.mean(), inplace=True)

# %%
dataset.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
import seaborn as sns
sns.heatmap(dataset.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
sns.heatmap(dataset.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(dataset['price'])
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.lineplot(dataset['price'],dataset['area'])
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price', ylabel='area'>

# %%
sns.barplot((dataset.price.value_counts()).index,dataset.price.value_counts())
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='price'>

# %%
print('skewness value of price: ',dataset['price'].skew())
print('skewness value of area: ',dataset['area'].skew())
# Out:
# skewness value of price:  1.2122388370279802
# skewness value of area:  1.321188343153483

# %%
sns.boxplot(dataset['price'],data=dataset)
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='price'>

# %%
##7. Check for Categorical columns and perform encoding.

dataset=pd.read_csv('Housing.csv')

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
dataset.airconditioning=le.fit_transform(dataset.airconditioning)

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating  airconditioning  parking furnishingstatus
# 0              no                1        2        furnished
# 1              no                1        3        furnished
# 2              no                0        2   semi-furnished
# 3              no                1        3        furnished
# 4              no                1        2        furnished

# %%
dataset.hotwaterheating=le.fit_transform(dataset.hotwaterheating)

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#    hotwaterheating  airconditioning  parking furnishingstatus
# 0                0                1        2        furnished
# 1                0                1        3        furnished
# 2                0                0        2   semi-furnished
# 3                0                1        3        furnished
# 4                0                1        2        furnished

# %%
dataset=pd.get_dummies(dataset,columns=['furnishingstatus'])

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#    hotwaterheating  airconditioning  parking  furnishingstatus_furnished  \
# 0                0                1        2                           1
# 1                0                1        3                           1
# 2                0                0        2                           0
# 3                0                1        3                           1
# 4                0                1        2                           1
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# ...

# %%
dataset.corr()
# Out:
#                                     price      area  bedrooms  bathrooms  \
# price                            1.000000  0.535997  0.366494   0.517545
# area                             0.535997  1.000000  0.151858   0.193820
# bedrooms                         0.366494  0.151858  1.000000   0.373930
# bathrooms                        0.517545  0.193820  0.373930   1.000000
# stories                          0.420712  0.083996  0.408564   0.326165
# hotwaterheating                  0.093073 -0.009229  0.046049   0.067159
# airconditioning                  0.452954  0.222393  0.160603   0.186915
# parking                          0.384394  0.352980  0.139270   0.177496
# furnishingstatus_furnished       0.229350  0.145772  0.079054   0.108139
# furnishingstatus_semi-furnished  0.063656  0.006156  0.050040   0.029834
# furnishingstatus_unfurnished    -0.280587 -0.142278 -0.126252  -0.132107
#
#                                   stories  hotwaterheating  airconditioning  \
# ...

# %%
##8. Split the data into dependent and independent variables
y=dataset['airconditioning']

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: airconditioning, dtype: int32

# %%
x=dataset.drop(columns=['area'],axis=1)
x.head()
# Out:
#       price  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000         4          2        3      yes        no       no
# 1  12250000         4          4        4      yes        no       no
# 2  12250000         3          2        2      yes        no      yes
# 3  12215000         4          2        2      yes        no      yes
# 4  11410000         4          1        2      yes       yes      yes
#
#    hotwaterheating  airconditioning  parking  furnishingstatus_furnished  \
# 0                0                1        2                           1
# 1                0                1        3                           1
# 2                0                0        2                           0
# 3                0                1        3                           1
# 4                0                1        2                           1
#
#    furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# ...

# %%
##9. Scale the independent variables
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()

# %%
scale = StandardScaler()

# %%
dataset=pd.read_csv('Housing.csv')

# %%
dataset.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
X = dataset[['price', 'area']]

# %%
scaledX = scale.fit_transform(X)

# %%
print(scaledX)
# Out:
# [[ 4.56636513  1.04672629]
#  [ 4.00448405  1.75700953]
#  [ 4.00448405  2.21823241]
#  ...
#  [-1.61432675 -0.70592066]
#  [-1.61432675 -1.03338891]
#  [-1.61432675 -0.5998394 ]]

# %%
name=X.columns

# %%
name
# Out:
# Index(['price', 'area'], dtype='object')

# %%
X=pd.DataFrame(scaledX,columns=name)

# %%
X
# Out:
#         price      area
# 0    4.566365  1.046726
# 1    4.004484  1.757010
# 2    4.004484  2.218232
# 3    3.985755  1.083624
# 4    3.554979  1.046726
# ..        ...       ...
# 540 -1.576868 -0.991879
# 541 -1.605149 -1.268613
# 542 -1.614327 -0.705921
# 543 -1.614327 -1.033389
# 544 -1.614327 -0.599839
#
# [545 rows x 2 columns]

# %%
##10. Split the data into training and testing

from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#         price      area
# 542 -1.614327 -0.705921
# 496 -1.108634 -0.530656
# 484 -1.014987 -0.973430
# 507 -1.164822 -0.715145
# 252 -0.134707  2.172110

# %%
X_test.head()
# Out:
#         price      area
# 239 -0.097248 -0.530656
# 113  0.704369  2.061417
# 325 -0.406282 -0.779716
# 66   1.157620  3.712595
# 479 -0.977528 -0.687472

# %%
y_train
# Out:
# 542    0
# 496    0
# 484    0
# 507    0
# 252    0
#       ..
# 70     1
# 277    0
# 9      1
# 359    0
# 192    0
# Name: airconditioning, Length: 436, dtype: int32

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.drop(columns=['furnishingstatus'],inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking
# 0              no             yes        2
# 1              no             yes        3
# 2              no              no        2
# 3              no             yes        3
# 4              no             yes        2

# %%
df.isnull().sum()
# Out:
# price              0
# area               0
# bedrooms           0
# bathrooms          0
# stories            0
# mainroad           0
# guestroom          0
# basement           0
# hotwaterheating    0
# airconditioning    0
# parking            0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            545 non-null    int64
#  1   area             545 non-null    int64
#  2   bedrooms         545 non-null    int64
#  3   bathrooms        545 non-null    int64
#  4   stories          545 non-null    int64
#  5   mainroad         545 non-null    object
#  6   guestroom        545 non-null    object
#  7   basement         545 non-null    object
#  8   hotwaterheating  545 non-null    object
#  9   airconditioning  545 non-null    object
#  10  parking          545 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 47.0+ KB

# %%
df["mainroad"].replace({'yes':1,'no':0},inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 0  13300000  7420         4          2        3         1        no       no
# 1  12250000  8960         4          4        4         1        no       no
# 2  12250000  9960         3          2        2         1        no      yes
# 3  12215000  7500         4          2        2         1        no      yes
# 4  11410000  7420         4          1        2         1       yes      yes
#
#   hotwaterheating airconditioning  parking
# 0              no             yes        2
# 1              no             yes        3
# 2              no              no        2
# 3              no             yes        3
# 4              no             yes        2

# %%
df["guestroom"].replace({'yes':1,'no':0},inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom basement  \
# 0  13300000  7420         4          2        3         1          0       no
# 1  12250000  8960         4          4        4         1          0       no
# 2  12250000  9960         3          2        2         1          0      yes
# 3  12215000  7500         4          2        2         1          0      yes
# 4  11410000  7420         4          1        2         1          1      yes
#
#   hotwaterheating airconditioning  parking
# 0              no             yes        2
# 1              no             yes        3
# 2              no              no        2
# 3              no             yes        3
# 4              no             yes        2

# %%
df["basement"].replace({'yes':1,'no':0},inplace=True)

# %%
df["hotwaterheating"].replace({'yes':1,'no':0},inplace=True)

# %%
df["airconditioning"].replace({'yes':1,'no':0},inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking
# 0         0                0                1        2
# 1         0                0                1        3
# 2         1                0                0        2
# 3         1                0                1        3
# 4         1                0                1        2

# %%
x=df.iloc[:,0:1]

# %%
x.head()
# Out:
#       price
# 0  13300000
# 1  12250000
# 2  12250000
# 3  12215000
# 4  11410000

# %%
y=df.iloc[:,1:]

# %%
y.head()
# Out:
#    area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0  7420         4          2        3         1          0         0
# 1  8960         4          4        4         1          0         0
# 2  9960         3          2        2         1          0         1
# 3  7500         4          2        2         1          0         1
# 4  7420         4          1        2         1          1         1
#
#    hotwaterheating  airconditioning  parking
# 0                0                1        2
# 1                0                1        3
# 2                0                0        2
# 3                0                1        3
# 4                0                1        2

# %%
#Splitting the dataset into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (436, 1)
# (109, 1)
# (436, 10)
# (109, 10)

# %%
#11. Build the Model
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
#12. Train the Model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#13. Test the Model

y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([[5.03689044e+03, 2.93199444e+00, 1.25495802e+00, ...,
#         3.66092667e-02, 3.02570966e-01, 6.82513429e-01],
#        [5.92892011e+03, 3.15762339e+00, 1.44826656e+00, ...,
#         5.51291200e-02, 4.64502173e-01, 9.39777884e-01],
#        [4.69300049e+03, 2.84501132e+00, 1.18043487e+00, ...,
#         2.94696036e-02, 2.40144215e-01, 5.83334376e-01],
#        ...,
#        [4.76177848e+03, 2.86240794e+00, 1.19533950e+00, ...,
#         3.08975362e-02, 2.52629565e-01, 6.03170187e-01],
#        [4.14069240e+03, 2.70531115e+00, 1.06074617e+00, ...,
#         1.80028720e-02, 1.39883071e-01, 4.24046805e-01],
#        [5.59961944e+03, 3.07433046e+00, 1.37690499e+00, ...,
#         4.82923518e-02, 4.04723830e-01, 8.44806426e-01]])

# %%
y_test
# Out:
#       area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 239   4000         3          1        2         1          0         0
# 113   9620         3          1        1         1          0         1
# 325   3460         4          1        2         1          0         0
# 66   13200         2          1        1         1          0         1
# 479   3660         4          1        2         0          0         0
# ..     ...       ...        ...      ...       ...        ...       ...
# 76    6420         3          2        3         1          0         0
# 132   5200         3          1        3         1          0         0
# 311   6060         2          1        1         1          0         1
# 464   4500         2          1        2         1          0         0
# 155   6100         3          2        1         1          0         1
#
#      hotwaterheating  airconditioning  parking
# 239                0                0        1
# ...

# %%
E=y_test-y_pred
E
# Out:
#             area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 239 -1036.890437  0.068006  -0.254958  0.222050  0.145102  -0.165687
# 113  3691.079889 -0.157623  -0.448267 -1.060003  0.069043  -0.250592
# 325 -1233.000492  1.154989  -0.180435  0.330786  0.174424  -0.132955
# 66   6766.707970 -1.285199  -0.557567 -1.219482  0.026037  -0.298599
# 479  -397.325140  1.315776  -0.042680  0.531782 -0.771375  -0.072450
# ..           ...       ...        ...       ...       ...        ...
# 76    153.442489 -0.243025   0.478565  0.833238  0.040254  -0.282729
# 132  -566.353955 -0.116504  -0.413037  0.991399  0.082904  -0.235119
# 311  1298.221519 -0.862408  -0.195339 -0.690961  0.168559  -0.139501
# 464   359.307600 -0.705311  -0.060746  0.505422  0.221517  -0.080385
# 155   500.380563 -0.074330   0.623095 -0.955880  0.097121  -0.219249
#
#      basement  hotwaterheating  airconditioning   parking
# 239 -0.317177        -0.036609        -0.302571  0.317487
# ...

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_pred,y_test)
acc
# Out:
# -24.194906753271688

# %%
y_pr=lr.predict([[12]])
y_pr
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[ 2.30661984e+03,  2.24140297e+00,  6.63290911e-01,
#          9.14657308e-01,  6.22100228e-01, -9.41851125e-02,
#          6.00173275e-02, -2.00751828e-02, -1.93058301e-01,
#         -1.04906087e-01]])

# %%
#14. Measure the performance using Metrics.
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %%
error=y_test-y_pred

# %%
error
# Out:
#             area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 239 -1036.890437  0.068006  -0.254958  0.222050  0.145102  -0.165687
# 113  3691.079889 -0.157623  -0.448267 -1.060003  0.069043  -0.250592
# 325 -1233.000492  1.154989  -0.180435  0.330786  0.174424  -0.132955
# 66   6766.707970 -1.285199  -0.557567 -1.219482  0.026037  -0.298599
# 479  -397.325140  1.315776  -0.042680  0.531782 -0.771375  -0.072450
# ..           ...       ...        ...       ...       ...        ...
# 76    153.442489 -0.243025   0.478565  0.833238  0.040254  -0.282729
# 132  -566.353955 -0.116504  -0.413037  0.991399  0.082904  -0.235119
# 311  1298.221519 -0.862408  -0.195339 -0.690961  0.168559  -0.139501
# 464   359.307600 -0.705311  -0.060746  0.505422  0.221517  -0.080385
# 155   500.380563 -0.074330   0.623095 -0.955880  0.097121  -0.219249
#
#      basement  hotwaterheating  airconditioning   parking
# 239 -0.317177        -0.036609        -0.302571  0.317487
# ...

# %%
a=error*error

# %%
a
# Out:
#              area  bedrooms  bathrooms   stories  mainroad  guestroom  \
# 239  1.075142e+06  0.004625   0.065004  0.049306  0.021055   0.027452
# 113  1.362407e+07  0.024845   0.200943  1.123606  0.004767   0.062796
# 325  1.520290e+06  1.333999   0.032557  0.109419  0.030424   0.017677
# 66   4.578834e+07  1.651736   0.310881  1.487136  0.000678   0.089162
# 479  1.578673e+05  1.731266   0.001822  0.282792  0.595019   0.005249
# ..            ...       ...        ...       ...       ...        ...
# 76   2.354460e+04  0.059061   0.229025  0.694286  0.001620   0.079936
# 132  3.207568e+05  0.013573   0.170600  0.982872  0.006873   0.055281
# 311  1.685379e+06  0.743747   0.038158  0.477427  0.028412   0.019461
# 464  1.291020e+05  0.497464   0.003690  0.255451  0.049070   0.006462
# 155  2.503807e+05  0.005525   0.388247  0.913707  0.009432   0.048070
#
#      basement  hotwaterheating  airconditioning   parking
# 239  0.100601         0.001340         0.091549  0.100798
# ...

# %%
mse=np.mean(a)
# Out:
# C:\Users\chand\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
mse
# Out:
# area               3.669180e+06
# bedrooms           4.800862e-01
# bathrooms          2.144713e-01
# stories            5.634178e-01
# mainroad           1.231950e-01
# guestroom          1.492790e-01
# basement           2.664550e-01
# hotwaterheating    6.959897e-02
# airconditioning    1.540718e-01
# parking            5.372659e-01
# dtype: float64

# %%
mse2=mean_squared_error(y_test,y_pred)

# %%
mse2
# Out:
# 366918.209940432

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 144.61619494728427

# %%
rmse=np.sqrt(mse2)

# %%
rmse
# Out:
# 605.7377402312258

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.1282162214706745
